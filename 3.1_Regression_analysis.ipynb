# %%
from AfricaBorderConflictRegression_functions import *

# %%
grid_10km = import_geopackage("../Data/Regression_data/Africa-border-conflict_regression-data_102022.gpkg", "grid_10km_102022")
grid_25km = import_geopackage("../Data/Regression_data/Africa-border-conflict_regression-data_102022.gpkg", "grid_25km_102022")
grid_50km = import_geopackage("../Data/Regression_data/Africa-border-conflict_regression-data_102022.gpkg", "grid_50km_102022")
grid_100km = import_geopackage("../Data/Regression_data/Africa-border-conflict_regression-data_102022.gpkg", "grid_100km_102022")

# %% [markdown]
# # 3.1 Regression Analysis

# %% [markdown]
# ### OLS Regression - no controls

# %%
grid = grid_50km
dist_cols = ["dist_national_borders_102023_km","dist_colonial_borders_102023_km","dist_religious_borders_102023_km","dist_ethnic_borders_102023_km",]
y_col = "count_total_aggregated"
models = {}
for d in dist_cols:
    df = grid[[d, y_col]].copy()
    df = df.replace([np.inf, -np.inf], np.nan).dropna()
    df["km_closer"] = (-df[d].astype(float)) / 100.0   # <-- now per 100 km closer
    y = df[y_col].astype(float)
    X = sm.add_constant(df["km_closer"])
    m = sm.OLS(y, X).fit(cov_type="HC1")
    models[d] = m
    print("\n" + "="*95)
    print(f"OLS Regression: increase in conflict count per 100km closer to border) | {d}")
    print("="*95)
    print(m.summary().tables[1])
# Out:
# ===============================================================================================
# OLS Regression: increase in conflict count per 100km closer to border) | dist_national_borders_102023_km
# ===============================================================================================
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         17.8474      1.122     15.901      0.000      15.647      20.047
# km_closer      0.9245      0.773      1.195      0.232      -0.592       2.441
# ==============================================================================
#
# ===============================================================================================
# OLS Regression: increase in conflict count per 100km closer to border) | dist_colonial_borders_102023_km
# ===============================================================================================
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         20.6095      1.098     18.774      0.000      18.458      22.761
# km_closer      1.6756      0.315      5.316      0.000       1.058       2.293
# ==============================================================================
#
# ===============================================================================================
# OLS Regression: increase in conflict count per 100km closer to border) | dist_religious_borders_102023_km
# ===============================================================================================
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         23.3170      1.620     14.395      0.000      20.142      26.492
# km_closer      0.9139      0.134      6.809      0.000       0.651       1.177
# ==============================================================================
#
# ===============================================================================================
# OLS Regression: increase in conflict count per 100km closer to border) | dist_ethnic_borders_102023_km
# ===============================================================================================
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         15.4601      0.984     15.704      0.000      13.531      17.390
# km_closer     -1.1386      1.334     -0.854      0.393      -3.752       1.475
# ==============================================================================

# %% [markdown]
# ### OLS with controls

# %%
grid = grid_50km
dist_cols = ["dist_national_borders_102023_km","dist_colonial_borders_102023_km","dist_religious_borders_102023_km","dist_ethnic_borders_102023_km"]
y_col = "count_total_aggregated"
models = {}
for d in dist_cols:
    cols = [d, y_col, "is_coastal", "pop_est", "road_km", "landcover_majority", "lisa_label"]
    df = grid[cols].copy()
    df = df.replace([np.inf, -np.inf], np.nan).dropna()
    df["km_closer"] = (-df[d].astype(float)) / 100.0
    df["log_pop"] = np.log(df["pop_est"].astype(float).clip(lower=1))
    df["log_road"] = np.log(df["road_km"].astype(float).clip(lower=1e-6))
    df["landcover_majority"] = df["landcover_majority"].astype("category")
    df["lisa_label"] = df["lisa_label"].astype("category")
    formula = f"""{y_col} ~ km_closer + is_coastal + log_pop + log_road + C(landcover_majority, Treatment(reference=11)) + C(lisa_label, Treatment(reference="Not signif"))"""
    m = smf.ols(formula, data=df).fit(cov_type="HC1")
    models[d] = m
    print(f"OLS with controls | increase in conflict count per 100km closer to border | {d}")
    print(m.summary().tables[1])
# Out:
# OLS with controls | increase in conflict count per 100km closer to border | dist_national_borders_102023_km
# ==========================================================================================================================
#                                                              coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  0.9086      1.152      0.788      0.430      -1.350       3.167
# C(landcover_majority, Treatment(reference=11))[T.1.0]      0.2523      7.489      0.034      0.973     -14.426      14.931
# C(landcover_majority, Treatment(reference=11))[T.2.0]      1.9078      1.744      1.094      0.274      -1.510       5.326
# C(landcover_majority, Treatment(reference=11))[T.4.0]    -11.2209      6.013     -1.866      0.062     -23.006       0.564
# C(landcover_majority, Treatment(reference=11))[T.5.0]     16.3109      7.714      2.114      0.034       1.192      31.430
# C(landcover_majority, Treatment(reference=11))[T.7.0]    294.4671     66.308      4.441      0.000     164.505     424.429
# C(landcover_majority, Treatment(reference=11))[T.8.0]     -0.0827      1.085     -0.076      0.939      -2.209       2.043
# C(lisa_label, Treatment(reference="Not signif"))[T.HH]    69.4662      4.955     14.021      0.000      59.756      79.177
# C(lisa_label, Treatment(reference="Not signif"))[T.HL]     6.2216      3.611      1.723      0.085      -0.855      13.299
# C(lisa_label, Treatment(reference="Not signif"))[T.LH]    -5.2896      0.771     -6.861      0.000      -6.801      -3.778
# C(lisa_label, Treatment(reference="Not signif"))[T.LL]    -2.0730      0.636     -3.261      0.001      -3.319      -0.827
# km_closer                                                 -0.7514      0.864     -0.870      0.384      -2.445       0.942
# is_coastal                                                13.4477      5.618      2.394      0.017       2.436      24.459
# log_pop                                                   -0.2894      0.125     -2.306      0.021      -0.535      -0.043
# log_road                                                   0.2588      0.042      6.237      0.000       0.178       0.340
# ==========================================================================================================================
# OLS with controls | increase in conflict count per 100km closer to border | dist_colonial_borders_102023_km
# ==========================================================================================================================
#                                                              coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  1.6446      1.020      1.613      0.107      -0.354       3.643
# C(landcover_majority, Treatment(reference=11))[T.1.0]     -0.0022      7.485     -0.000      1.000     -14.672      14.667
# C(landcover_majority, Treatment(reference=11))[T.2.0]      1.8337      1.724      1.064      0.287      -1.545       5.212
# C(landcover_majority, Treatment(reference=11))[T.4.0]    -11.9004      6.056     -1.965      0.049     -23.771      -0.030
# C(landcover_majority, Treatment(reference=11))[T.5.0]     16.9964      7.455      2.280      0.023       2.386      31.607
# C(landcover_majority, Treatment(reference=11))[T.7.0]    294.4312     66.396      4.434      0.000     164.297     424.565
# C(landcover_majority, Treatment(reference=11))[T.8.0]      0.0952      1.126      0.085      0.933      -2.112       2.302
# C(lisa_label, Treatment(reference="Not signif"))[T.HH]    69.2374      4.798     14.429      0.000      59.833      78.642
# C(lisa_label, Treatment(reference="Not signif"))[T.HL]     6.4411      3.586      1.796      0.072      -0.588      13.470
# C(lisa_label, Treatment(reference="Not signif"))[T.LH]    -5.3718      0.753     -7.133      0.000      -6.848      -3.896
# C(lisa_label, Treatment(reference="Not signif"))[T.LL]    -1.8922      0.602     -3.141      0.002      -3.073      -0.712
# km_closer                                                 -0.1409      0.369     -0.382      0.702      -0.864       0.582
# is_coastal                                                14.0181      5.588      2.508      0.012       3.065      24.971
# log_pop                                                   -0.2879      0.124     -2.313      0.021      -0.532      -0.044
# log_road                                                   0.2778      0.047      5.866      0.000       0.185       0.371
# ==========================================================================================================================
# OLS with controls | increase in conflict count per 100km closer to border | dist_religious_borders_102023_km
# ==========================================================================================================================
#                                                              coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  1.8266      1.353      1.350      0.177      -0.826       4.479
# C(landcover_majority, Treatment(reference=11))[T.1.0]     -0.1521      7.591     -0.020      0.984     -15.030      14.726
# C(landcover_majority, Treatment(reference=11))[T.2.0]      1.7799      1.934      0.920      0.357      -2.011       5.571
# C(landcover_majority, Treatment(reference=11))[T.4.0]    -11.9380      6.276     -1.902      0.057     -24.239       0.363
# C(landcover_majority, Treatment(reference=11))[T.5.0]     17.0490      7.331      2.326      0.020       2.681      31.417
# C(landcover_majority, Treatment(reference=11))[T.7.0]    294.3745     66.406      4.433      0.000     164.220     424.528
# C(landcover_majority, Treatment(reference=11))[T.8.0]      0.2233      0.815      0.274      0.784      -1.374       1.820
# C(lisa_label, Treatment(reference="Not signif"))[T.HH]    69.2682      4.696     14.752      0.000      60.065      78.471
# C(lisa_label, Treatment(reference="Not signif"))[T.HL]     6.3702      3.635      1.752      0.080      -0.754      13.495
# C(lisa_label, Treatment(reference="Not signif"))[T.LH]    -5.3536      0.754     -7.098      0.000      -6.832      -3.875
# C(lisa_label, Treatment(reference="Not signif"))[T.LL]    -1.9259      0.663     -2.906      0.004      -3.225      -0.627
# km_closer                                                 -0.0248      0.109     -0.227      0.820      -0.238       0.189
# is_coastal                                                13.9649      5.623      2.483      0.013       2.944      24.986
# log_pop                                                   -0.2876      0.125     -2.297      0.022      -0.533      -0.042
# log_road                                                   0.2721      0.045      6.080      0.000       0.184       0.360
# ==========================================================================================================================
# OLS with controls | increase in conflict count per 100km closer to border | dist_ethnic_borders_102023_km
# ==========================================================================================================================
#                                                              coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  0.1376      1.280      0.107      0.914      -2.371       2.646
# C(landcover_majority, Treatment(reference=11))[T.1.0]      0.7164      7.471      0.096      0.924     -13.927      15.360
# C(landcover_majority, Treatment(reference=11))[T.2.0]      2.7416      1.707      1.606      0.108      -0.604       6.087
# C(landcover_majority, Treatment(reference=11))[T.4.0]     -9.4448      5.548     -1.702      0.089     -20.318       1.429
# C(landcover_majority, Treatment(reference=11))[T.5.0]     16.7063      7.444      2.244      0.025       2.116      31.297
# C(landcover_majority, Treatment(reference=11))[T.7.0]    295.5880     66.233      4.463      0.000     165.774     425.402
# C(landcover_majority, Treatment(reference=11))[T.8.0]     -0.3564      1.016     -0.351      0.726      -2.348       1.635
# C(lisa_label, Treatment(reference="Not signif"))[T.HH]    69.7885      4.941     14.125      0.000      60.105      79.472
# C(lisa_label, Treatment(reference="Not signif"))[T.HL]     6.4388      3.589      1.794      0.073      -0.596      13.474
# C(lisa_label, Treatment(reference="Not signif"))[T.LH]    -5.2928      0.763     -6.938      0.000      -6.788      -3.798
# C(lisa_label, Treatment(reference="Not signif"))[T.LL]    -1.6166      0.669     -2.416      0.016      -2.928      -0.305
# km_closer                                                 -2.3147      1.240     -1.867      0.062      -4.745       0.115
# is_coastal                                                11.8267      5.149      2.297      0.022       1.734      21.919
# log_pop                                                   -0.2851      0.124     -2.294      0.022      -0.529      -0.042
# log_road                                                   0.2465      0.039      6.293      0.000       0.170       0.323
# ==========================================================================================================================

# %% [markdown]
# ### Statistically significant & positive coefficents for proximity to border

# %%
grid = grid_50km
dist_cols = ["dist_national_borders_102023_km","dist_colonial_borders_102023_km","dist_religious_borders_102023_km","dist_ethnic_borders_102023_km"]
count_cols = ["count_total_aggregated","count_battles", "count_explosions_remote_violence", "count_protests","count_riots", "count_strategic_developments","count_violence_against_civilians", "count_total_disaggregated","count_abduction_forced_disappearance", "count_agreement","count_air_drone_strike", "count_armed_clash", "count_arrests","count_attack", "count_change_to_group_activity","count_chemical_weapon", "count_disrupted_weapons_use","count_excessive_force_against_protesters","count_government_regains_territory", "count_grenade","count_headquarters_or_base_established","count_looting_property_destruction", "count_mob_violence","count_non_state_actor_overtakes_territory","count_non_violent_transfer_of_territory", "count_other","count_peaceful_protest", "count_protest_with_intervention","count_remote_explosive_landmine_ied", "count_sexual_violence", "count_shelling_artillery_missile_attack", "count_suicide_bomb","count_violent_demonstration", "count_total_subevent","fatalities_total",]
controls = ["is_coastal", "pop_est", "road_km", "landcover_majority", "lisa_label"]
alpha = 0.01
results_by_border = {}
sig_by_border = {}

for d in dist_cols:
    rows = []
    for y_col in count_cols:
        cols = [d, y_col] + controls
        df = grid[cols].copy().replace([np.inf, -np.inf], np.nan).dropna()
        if df.empty or df[y_col].nunique() < 2 or df[d].nunique() < 2:
            continue
        df["km_closer"] = (-df[d].astype(float)) / 100.0
        df["log_pop"]  = np.log(df["pop_est"].astype(float).clip(lower=1))
        df["log_road"] = np.log(df["road_km"].astype(float).clip(lower=1e-6))
        df["landcover_majority"] = df["landcover_majority"].astype("category")
        df["lisa_label"] = df["lisa_label"].astype("category")
        formula = (f"{y_col} ~ km_closer + is_coastal + log_pop + log_road + C(landcover_majority, Treatment(reference=11)) + C(lisa_label, Treatment(reference='Not signif'))")
        try:
            m = smf.ols(formula, data=df).fit(cov_type="HC1")
        except Exception:
            continue
        rows.append({"outcome": y_col,"coef_km_closer_per100km": float(m.params["km_closer"]),"p_value": float(m.pvalues["km_closer"]),"r2": float(m.rsquared)})
    res = pd.DataFrame(rows).sort_values("p_value")
    results_by_border[d] = res
    sig = res[(res["coef_km_closer_per100km"] > 0) & (res["p_value"] < alpha)].copy()
    sig_by_border[d] = sig
for d in dist_cols:
    print(f"Positive km_closer effects only (per 100 km closer), p < {alpha} | {d}")
    display(sig_by_border[d] if not sig_by_border[d].empty else pd.DataFrame(columns=["outcome","coef_km_closer_per100km","p_value","r2"]))
# Out:
# Positive km_closer effects only (per 100 km closer), p < 0.01 | dist_national_borders_102023_km
#                                    outcome  coef_km_closer_per100km   p_value  \
# 20  count_headquarters_or_base_established                 0.003927  0.000004
# 22                      count_mob_violence                 0.129235  0.000013
# 21      count_looting_property_destruction                 0.121507  0.002621
#
#           r2
# 20  0.015546
# 22  0.165336
# 21  0.051851
# Positive km_closer effects only (per 100 km closer), p < 0.01 | dist_colonial_borders_102023_km
#                                     outcome  coef_km_closer_per100km  \
# 22                       count_mob_violence                 0.097886
# 20   count_headquarters_or_base_established                 0.002774
# 24  count_non_violent_transfer_of_territory                 0.008695
# 8      count_abduction_forced_disappearance                 0.061752
# 9                           count_agreement                 0.008180
# 6          count_violence_against_civilians                 0.181580
# 12                            count_arrests                 0.008251
#
#          p_value        r2
# 22  3.620871e-08  0.165551
# 20  1.425296e-06  0.015575
# 24  7.652752e-05  0.025344
# 8   2.220361e-03  0.070746
# 9   3.725951e-03  0.021797
# 6   4.561163e-03  0.123728
# 12  9.707750e-03  0.049222
# Positive km_closer effects only (per 100 km closer), p < 0.01 | dist_religious_borders_102023_km
#                                       outcome  coef_km_closer_per100km  \
# 34                           fatalities_total                 1.531082
# 13                               count_attack                 0.182536
# 6            count_violence_against_civilians                 0.244141
# 5                count_strategic_developments                 0.118323
# 8        count_abduction_forced_disappearance                 0.055025
# 25                                count_other                 0.021506
# 1                               count_battles                 0.245898
# 11                          count_armed_clash                 0.239616
# 29                      count_sexual_violence                 0.006580
# 21         count_looting_property_destruction                 0.062234
# 14             count_change_to_group_activity                 0.014800
# 23  count_non_state_actor_overtakes_territory                 0.003625
# 22                         count_mob_violence                 0.044015
# 12                              count_arrests                 0.009154
# 10                     count_air_drone_strike                 0.020931
# 9                             count_agreement                 0.004182
# 17   count_excessive_force_against_protesters                 0.003594
# 20     count_headquarters_or_base_established                 0.000560
# 28        count_remote_explosive_landmine_ied                 0.018807
# 18         count_government_regains_territory                 0.002657
# 16                count_disrupted_weapons_use                 0.004319
# 19                              count_grenade                 0.003139
# 24    count_non_violent_transfer_of_territory                 0.001569
#
#          p_value        r2
# 34  1.616611e-46  0.096599
# 13  2.987353e-39  0.133533
# 6   2.316464e-38  0.127639
# 5   1.499750e-23  0.076880
# 8   1.493347e-22  0.072837
# 25  1.983101e-21  0.053660
# 1   8.325106e-19  0.047128
# 11  1.507182e-18  0.046900
# 29  2.938189e-17  0.036620
# 21  3.076715e-14  0.053731
# 14  1.228909e-13  0.028808
# 23  8.883551e-13  0.012053
# 22  6.627806e-11  0.166369
# 12  2.412558e-09  0.050799
# 10  3.274603e-08  0.008636
# 9   6.878358e-07  0.022280
# 17  6.234709e-06  0.003839
# 20  6.690156e-06  0.015250
# 28  3.503516e-04  0.023261
# 18  6.125333e-04  0.020771
# 16  4.449521e-03  0.053291
# 19  5.085317e-03  0.007889
# 24  6.023873e-03  0.025115
# Positive km_closer effects only (per 100 km closer), p < 0.01 | dist_ethnic_borders_102023_km
#                                  outcome  coef_km_closer_per100km  \
# 22                    count_mob_violence                 0.219426
# 12                         count_arrests                 0.029381
# 21    count_looting_property_destruction                 0.149952
# 8   count_abduction_forced_disappearance                 0.109212
#
#          p_value        r2
# 22  4.056126e-07  0.165808
# 12  2.425476e-05  0.049573
# 21  2.815901e-04  0.051742
# 8   1.250317e-03  0.070657
